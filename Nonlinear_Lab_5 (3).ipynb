# %% [markdown]
# # Logistic Map Part 2: Poincaré Plots, Bifurcation Diagrams, and Cobweb Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def logistic(r, x):
    return r * x * (1 - x)

# %%
n = 100
r = np.linspace(2.5, 4.0, n)

# %%
x = 1e-5 * np.ones(n)

# %%
iterations = 150

# %%
x = logistic(r, x)

# %%
X = np.zeros((iterations,n))

# %%
for i in range(1,iterations):
    
    x = logistic(r, x) 

    X[i,:] = x

# %%
plt.plot(X[:,[1]])

# %%
plt.plot(X[:,80],'.')

# %%
n1 = 96

# %%
r[n1]
# Out:
# 3.9545454545454546

# %% [markdown]
# # Poincaré Plots

# %%
X[0:-1,n1] #Skip last value
# Out:
# array([0.00000000e+00, 1.56376550e-04, 6.18301470e-04, 2.44358946e-03,
#        9.63967248e-03, 3.77530536e-02, 1.43659780e-01, 4.86494699e-01,
#        9.87915082e-01, 4.72128166e-02, 1.77890349e-01, 5.78333975e-01,
#        9.64370436e-01, 1.35878571e-01, 4.64325269e-01, 9.83603467e-01,
#        6.37776696e-02, 2.36126219e-01, 7.13283846e-01, 8.08744094e-01,
#        6.11677560e-01, 9.39315757e-01, 2.25415677e-01, 6.90477278e-01,
#        8.45159153e-01, 5.17512221e-01, 9.87423592e-01, 4.91085022e-02,
#        1.84664844e-01, 5.95411152e-01, 9.52636998e-01, 1.78428095e-01,
#        5.79702790e-01, 9.63514976e-01, 1.39017564e-01, 4.73326192e-01,
#        9.85822736e-01, 5.52697916e-02, 2.06486756e-01, 6.47952176e-01,
#        9.02071971e-01, 3.49337152e-01, 8.98870975e-01, 3.59475876e-01,
#        9.10545838e-01, 3.22106092e-01, 8.63489859e-01, 4.66142530e-01,
#        9.84103156e-01, 6.18654395e-02, 2.29514332e-01, 6.99311945e-01,
#        8.31541052e-01, 5.53954827e-01, 9.77124194e-01, 8.83939918e-02,
#        3.18659226e-01, 8.58593208e-01, 4.80124967e-01, 9.87074251e-01,
#        5.04547553e-02, 1.89458607e-01, 6.07275988e-01, 9.43126910e-01,
#        2.12116051e-01, 6.60894835e-01, 8.86264461e-01, 3.98617257e-01,
#        9.47989724e-01, 1.94979681e-01, 6.20715757e-01, 9.31009565e-01,
#        2.54003441e-01, 7.49329785e-01, 7.42800694e-01, 7.55507300e-01,
#        7.30467896e-01, 7.78588897e-01, 6.81717077e-01, 8.58052938e-01,
#        4.81656096e-01, 9.87305664e-01, 4.95630695e-02, 1.86285079e-01,
#        5.99441659e-01, 9.49531274e-01, 1.89508280e-01, 6.07397982e-01,
#        9.43023345e-01, 2.12478976e-01, 6.61720660e-01, 8.85210875e-01,
#        4.01831572e-01, 9.50526250e-01, 1.85966843e-01, 5.98651651e-01,
#        9.50150141e-01, 1.87306454e-01, 6.01971769e-01, 9.47516045e-01,
#        1.96657132e-01, 6.24751369e-01, 9.27092153e-01, 2.67296796e-01,
#        7.74494638e-01, 6.90672015e-01, 8.44865631e-01, 5.18313163e-01,
#        1.87306454e-01, 6.01971769e-01, 9.47516045e-01, 1.96657132e-01,
#        6.24751369e-01, 9.27092153e-01, 2.67296796e-01, 7.74494638e-01,
#        6.90672015e-01, 8.44865631e-01, 5.18313163e-01, 9.87310120e-01,
#        4.95458948e-02, 1.86223892e-01, 5.99289827e-01, 9.49650597e-01,
#        1.89083983e-01, 6.06355320e-01, 9.43904704e-01, 2.09387700e-01,
#        6.54653214e-01, 8.94053061e-01, 3.74583186e-01, 9.26433827e-01,
#        2.69518847e-01, 7.78564733e-01, 6.81770317e-01, 8.57976410e-01,
#        4.81872793e-01, 9.87336917e-01, 4.94426106e-02, 1.85855881e-01,
#        5.98376005e-01, 9.50364912e-01, 1.86541628e-01, 6.00077949e-01,
#        9.49029235e-01, 1.91292224e-01, 6.11766240e-01, 9.39237398e-01,
#        2.25687919e-01, 6.91068216e-01, 8.44267522e-01, 5.19943135e-01,
#        9.87063528e-01, 5.04960653e-02, 1.89605478e-01, 6.07636633e-01,
#        9.42820405e-01, 2.13189897e-01, 6.63335314e-01, 8.83135320e-01,
#        4.08138066e-01])

# %%
plt.plot(X[0:-1,n1],X[1:,n1],'.')

# %%
X.shape
# Out:
# (150, 100)

# %%
X1 = np.random.random(X.shape)

# %%
plt.plot(X1[0:-1,n1],X1[1:,n1],'.')

# %% [markdown]
# # Bifurcation Diagrams

# %%
n = 100
r = np.linspace(2.5, 4.0, n)

# %%
x = 1e-5 * np.ones(n)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,10))
ax1.plot(r, x, '.', alpha=.25,markersize=10)

# %%
iterations = 150

# %%
x = logistic(r, x)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,10))
ax1.plot(r, x, '.', alpha=.25, markersize=10)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(10,10))

for i in range(1,iterations):

    x = logistic(r, x)

    ax1.plot(r, x, '.b', alpha = (i + 1) / iterations)

# %% [markdown]
# # Cobweb Plots

# %% [markdown]
# <img src='https://upload.wikimedia.org/wikipedia/commons/e/ed/LogisticCobwebChaos.gif'>
#
# An animated cobweb diagram of the logistic map $y = r x (1-x)$, showing chaotic behaviour for most values of $r > 3.57$.

# %%
x = np.linspace(0, 1)
fig, ax = plt.subplots(1, 1)
ax.plot(x, logistic(2, x), 'k')

# %%
def plot_system(r, x0, n):
    
    t = np.linspace(0, 1)

    fig, ax = plt.subplots(1, 1, figsize=(10, 10))
    ax.plot(t, logistic(r, t), 'k', lw=2)
    ax.plot([0, 1], [0, 1], 'k', lw=2)

    x = x0
    for i in range(n):
        
        y = logistic(r, x)

        ax.plot([x, x], [x, y], 'k', lw=1)
        ax.plot([x, y], [y, y], 'k', lw=1)
        ax.plot([x], [y], 'ok', ms=10, alpha=(i + 1) / n)

        x = y

    
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    ax.set_title(f"$r={r:.1f}, \, x_0={x0:.1f}$")

# %%
plot_system(2.6, .1, 10)

# %%
plot_system(3.2, .1, 10)

# %%
plot_system(3.9, .1, 10)
